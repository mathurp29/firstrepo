# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Prash**
# Occupation: Manager

# %% [markdown]
# *I am interested in data science because i am a analytics professional. i am looking forward to learn new skills.*

# %% [markdown]
# ### this is a simple code  calculate  product of 2 numbers

# %%
100*100
# Out:
# 10000

# %% [markdown]
# -bullet list 1
#     - bullet list 2
#
# 1. Numbered list 1
# 2. Numbered list 2
#
# __(https://www.ibm.com/au-en)__
#
# *************************************
